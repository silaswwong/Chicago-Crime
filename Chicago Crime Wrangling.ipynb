# %%
import pandas as pd

# %%
df = pd.read_csv('chicago_crimes.csv',parse_dates=True)

# %%
df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
df1 = df[df['Primary Type']=='HOMICIDE']
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8991 entries, 641 to 6552245
# Data columns (total 22 columns):
# ID                      8991 non-null int64
# Case Number             8991 non-null object
# Date                    8991 non-null object
# Block                   8991 non-null object
# IUCR                    8991 non-null object
# Primary Type            8991 non-null object
# Description             8991 non-null object
# Location Description    8991 non-null object
# Arrest                  8991 non-null bool
# Domestic                8991 non-null bool
# Beat                    8991 non-null int64
# District                8991 non-null float64
# Ward                    8605 non-null float64
# Community Area          8605 non-null float64
# FBI Code                8991 non-null object
# X Coordinate            8908 non-null float64
# Y Coordinate            8908 non-null float64
# Year                    8991 non-null int64
# ...

# %%
df1.to_csv('homicide.csv')

# %%
type(df.Date[0])
# Out:
# str

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6552250 entries, 0 to 6552249
# Data columns (total 22 columns):
# ID                      int64
# Case Number             object
# Date                    datetime64[ns]
# Block                   object
# IUCR                    object
# Primary Type            object
# Description             object
# Location Description    object
# Arrest                  bool
# Domestic                bool
# Beat                    int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                object
# X Coordinate            float64
# Y Coordinate            float64
# Year                    int64
# Updated On              object
# Latitude                float64
# Longitude               float64
# Location                object
# dtypes: bool(2), datetime64[ns](1), float64(7), int64(3), object(9)
# memory usage: 1012.3+ MB

# %%
from bokeh.io import output_file, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource

# %%
source = ColumnDataSource(df)

# %%
plot = figure()

# %%
plot.circle('Latitude','Longitude',source=source)
# Out:
# GlyphRenderer(id='01c9c82b-a9a3-4923-9008-660b21160edd', ...)

# %%
df1 = df.head()
source1 = ColumnDataSource(df1)
plot1 = figure()
plot1.circle('Latitude','Longitude',source=source1)
# Out:
# GlyphRenderer(id='13d32a28-ec66-43eb-8ab5-baf6c0686354', ...)

# %%
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f6ff479a-a82c-42c8-9f07-23278d112315">Loading BokehJS ...</span>
#     </div>

# %%
show(plot1)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="da3aa480-e53a-4733-937e-7f3b97d72534"></div>
# </div>
